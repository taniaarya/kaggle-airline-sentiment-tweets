# %% [markdown]
# # **Intro to Data Visualization**
# #### By: Tania Arya
#
# *Originally presented in the QUESTech Datathon Workshop Series 2021*
#
# ---

# %% [markdown]
# # Setup

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# [Learn how to read data into a Pandas DataFrame in 5 minutes](https://towardsdatascience.com/learn-how-to-read-data-into-a-pandas-dataframe-in-5-minutes-122af8e0b9db)

# %%
# Read sqlite query results into a pandas DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/taniaarya/kaggle-airline-sentiment-tweets/main/Tweets.csv')

# Verify that result of SQL query is stored in the dataframe
df.head()
# Out:
#              tweet_id  ...               user_timezone
# 0  570306133677760513  ...  Eastern Time (US & Canada)
# 1  570301130888122368  ...  Pacific Time (US & Canada)
# 2  570301083672813571  ...  Central Time (US & Canada)
# 3  570301031407624196  ...  Pacific Time (US & Canada)
# 4  570300817074462722  ...  Pacific Time (US & Canada)
#
# [5 rows x 15 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# [Working with datetime in Pandas DataFrame](https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587)

# %%
# convert tweet created column to datetime objects
df['tweet_created'] = pd.to_datetime(df['tweet_created'])

# extract date from tweet created column (using built in datetime properties)
df["tweet_date"] = df['tweet_created'].dt.date

# %% [markdown]
# [How to drop one or multiple columns in Pandas Dataframe](https://www.geeksforgeeks.org/how-to-drop-one-or-multiple-columns-in-pandas-dataframe/)

# %%
# remove unnecessary columns
df.drop(columns=['airline_sentiment_gold', 'negativereason_gold'], inplace=True)

# %% [markdown]
# # Numerical Analysis

# %% [markdown]
# [Python | Pandas Dataframe.describe() method](https://www.geeksforgeeks.org/python-pandas-dataframe-describe-method/)

# %%
# descriptive statistics
df.describe()
# Out:
#            tweet_id  ...  retweet_count
# count  1.464000e+04  ...   14640.000000
# mean   5.692184e+17  ...       0.082650
# std    7.791112e+14  ...       0.745778
# min    5.675883e+17  ...       0.000000
# 25%    5.685592e+17  ...       0.000000
# 50%    5.694779e+17  ...       0.000000
# 75%    5.698905e+17  ...       0.000000
# max    5.703106e+17  ...      44.000000
#
# [8 rows x 4 columns]

# %% [markdown]
# Overview: [Python | Pandas dataframe.groupby()](https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/)
#
# In Depth Walkthrough: [Pandas GroupBy](https://www.geeksforgeeks.org/pandas-groupby/)
#
# Official Documentation: [GroupBy](https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html)

# %%
# counts for number of tweets per airline
df.groupby("airline").size()
# Out:
# airline
# American          2759
# Delta             2222
# Southwest         2420
# US Airways        2913
# United            3822
# Virgin America     504
# dtype: int64

# %%
# counts for tweets per sentiment
df.groupby("airline_sentiment").size()
# Out:
# airline_sentiment
# negative    9178
# neutral     3099
# positive    2363
# dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Plotly Express
#
# Interactive graphing library
#
# [Documentation](https://plotly.com/python/plotly-express/)
#
# [Overview](https://medium.com/plotly/introducing-plotly-express-808df010143d)
#
# [Comprehensive Guide](https://towardsdatascience.com/visualization-with-plotly-express-comprehensive-guide-eb5ee4b50b57)

# %% [markdown]
# ## Histograms

# %%
fig = px.histogram(df, x="airline", title="Counts of Tweets per Airline")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="27594dc0-4846-432d-8b6e-92dcac549520" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27594dc0-4846-432d-8b6e-92dcac549520")) {
#                     Plotly.newPlot(
#                         '27594dc0-4846-432d-8b6e-92dcac549520',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "airline=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virg
%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Bad Flight", "Can't Tell", "Can't Tell", "Late Flight", "Bad Flight", "Can't Tell", "Customer Service Issue", "Customer Service Issue", "Can't Tell", "Bad Flight", "Flight Booking Problems", "Customer Service Issue", "Customer Service Issue", "Customer Service Issue", "Flight Booking Problems", "Flight Booking Problems", "Customer Service Issue", "Customer Service Issue", "Late Flight", "Lost Luggage", "Flight Attendant Complaints", "Customer Service Issue", "Customer Service Issue", "Late Flight", "Can't Tell", "Can't Tell", "Flight Booking Problems", "Can't Tell", "Cancelled Flight", "Late Flight", "Customer Service Issue", "Customer Service Issue", "Can't Tell", "Flight Booking Problems", "Customer Service Issue", "Late Flight", "Late Flight", "Late Flight", "Customer Service Issue", "Flight Booking Problems", "Late Flight", "Customer Service Issue", "Flight Booking Problems", "Customer Service Issue", "Customer Service Issue", "Customer Service Issue", "Can't Tell", "Cancelled Flight", "Late Flight", "Customer Service Issue", "Flight Booking Problems", "Flight Attendant Complaints", "Late Flight", "Cancelled Flight", "Flight Booking Problems", "Damaged Luggage", "Damaged Luggage", "Customer Service Issue", "Cancelled Flight", "Flight Booking Problems", "Late Flight", "Cancelled Flight", "Bad Flight", "Customer Service Issue", "Customer Service Issue", "Customer Service Issue", "Customer Service Issue", "longlines", "Can't Tell", "Customer Service Issue", "Customer Service Issue", "Cancelled Flight", "Customer Service Issue", "Cancelled Flight", "Can't Tell", "Flight Attendant Complaints", "Flight Booking Problems", "Can't Tell", "Flight Booking Problems", "Cancelled Flight", "Flight Booking Problems", "Cancelled Flight", "Cancelled Flight", "Customer Service Issue", "Bad Flight", "Late Flight", "Cancelled Flight", "Cancelled Flight", "Customer Service Issue", "Customer Service Issue", "Cancelled Flight", "Cancelled Flight", "Customer Service Issue", "Flight Booking Problems", "Cancelled Flight", "Can't Tell", "Customer Service Issue", "Flight Booking Problems", "Customer Service Issue", "Late Flight", "Cancelled Flight", "Customer Service Issue", "Lost Luggage", "Customer Service Issue", "Bad Flight", "Flight Booking Problems", "Damaged Luggage", "Bad Flight", "Bad Flight", "Customer Service Issue", "Can't Tell", "Customer Service Issue", "Bad Flight", "Lost Luggage", "Customer Service Issue", "Can't Tell", "Flight Attendant Complaints", "Bad Flight", "Flight Booking Problems", "Customer Service Issue", "Customer Service Issue", "Lost Luggage", "Flight Booking Problems", "Can't Tell", "Flight Booking Problems", "Customer Service Issue", "Customer Service Issue", "Flight Booking Problems", "Lost Luggage", "Flight Booking Problems", "Flight Booking Problems", "Customer Service Issue", "Customer Service Issue", "Late Flight", "Customer Service Issue", "Can't Tell", "Flight Booking Problems", "Bad Flight", "longlines", "Customer Service Issue", "Flight Booking Problems", "Flight Booking Problems", "Can't Tell", "Bad Flight", "Bad Flight", "Customer Service Issue", "Late Flight", "Customer Service Issue", "Can't Tell", "Customer Service Issue", "Flight Booking Problems", "Customer Service Issue", "Bad Flight", "Bad Flight", "Customer Service Issue", "Customer Service Issue", "Customer Service Issue", "Can't Tell", "Can't Tell", "Customer Service Issue", "longlines", "Flight Booking Problems", "Bad Flight", "Bad Flight", "Cancelled Flight", "Can't Tell", "Damaged Luggage", "Flight Attendant Complaints", "Bad Flight", "Customer Service Issue", "Late Flight", "Customer Service Issue", "Customer Service Issue", "Cancelled Flight", ...

# %%
fig = px.histogram(df, x="airline", color="airline_sentiment", barmode="group", 
                   title="Counts of Tweets per Airline")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5ccba4f1-6a83-468b-98bd-42ae290b6fc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ccba4f1-6a83-468b-98bd-42ae290b6fc5")) {
#                     Plotly.newPlot(
#                         '5ccba4f1-6a83-468b-98bd-42ae290b6fc5',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "airline_sentiment=neutral<br>airline=%{x}<br>count=%{y}", "legendgroup": "airline_sentiment=neutral", "marker": {"color": "#636efa"}, "name": "airline_sentiment=neutral", "offsetgroup": "airline_sentiment=neutral", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United",  ...

# %%
# extract tweets that are negative because of a "customer service issue"
df_cs = df[df.negativereason == 'Customer Service Issue']

# setting the histnorm to percent normalizes the y-axis
fig = px.histogram(df_cs, x="airline", title="Counts of Tweets About Bad Customer Service", histnorm="percent")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f994eb9-42ba-45f7-be63-f362e4588b2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f994eb9-42ba-45f7-be63-f362e4588b2b")) {
#                     Plotly.newPlot(
#                         '3f994eb9-42ba-45f7-be63-f362e4588b2b',
#                         [{"alignmentgroup": "True", "bingroup": "x", "histnorm": "percent", "hoverlabel": {"namelength": 0}, "hovertemplate": "airline=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "Virgin America", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United", "United" ...

# %% [markdown]
# ## Timeseries

# %%
# get counts for each date, divided by sentiment
df_counts = df.groupby(['tweet_date', 'airline_sentiment']).size().reset_index(name="count")
df_counts
# Out:
#     tweet_date airline_sentiment  count
# 0   2015-02-16          negative      3
# 1   2015-02-16           neutral      1
# 2   2015-02-17          negative    838
# 3   2015-02-17           neutral    297
# 4   2015-02-17          positive    273
# 5   2015-02-18          negative    736
# 6   2015-02-18           neutral    335
# 7   2015-02-18          positive    273
# 8   2015-02-19          negative    751
# 9   2015-02-19           neutral    329
# 10  2015-02-19          positive    296
# 11  2015-02-20          negative    835
# 12  2015-02-20           neutral    383
# 13  2015-02-20          positive    282
# 14  2015-02-21          negative   1049
# 15  2015-02-21           neutral    278
# 16  2015-02-21          positive    230
# 17  2015-02-22          negative   2266
# 18  2015-02-22           neutral    463
# 19  2015-02-22          positive    350
# 20  2015-02-23          negative   1919
# 21  2015-02-23           neutral    676
# 22  2015-02-23          positive    433
# 23  2015-02-24          negative    781
# 24  2015-02-24           neutral    337
# 25  2015-02-24          positive    226

# %%
fig = px.line(df_counts, x='tweet_date', y="count", color='airline_sentiment', title="Sentiment of Tweets Over Time")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="17557343-accc-4147-a14a-de2236c4ca70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("17557343-accc-4147-a14a-de2236c4ca70")) {
#                     Plotly.newPlot(
#                         '17557343-accc-4147-a14a-de2236c4ca70',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "airline_sentiment=negative<br>tweet_date=%{x}<br>count=%{y}", "legendgroup": "airline_sentiment=negative", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "airline_sentiment=negative", "showlegend": true, "type": "scatter", "x": ["2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24"], "xaxis": "x", "y": [3, 838, 736, 751, 835, 1049, 2266, 1919, 781], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "airline_sentiment=neutral<br>tweet_date=%{x}<br>count=%{y}", "legendgroup": "airline_sentiment=neutral", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "airline_sentiment=neutral", "showlegend": true, "type": "scatter", "x": ["2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24"], "xaxis": "x", "y": [1, 297, 335, 329, 383, 278, 463, 676, 337], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "airline_sentiment=positive<br>tweet_date=%{x}<br>count=%{y}", "legendgroup": "airline_sentiment=positive", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "airline_sentiment=positive", "showlegend": true, "type": "scatter", "x": ["2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24"], "xaxis": "x", "y": [273, 273, 296, 282, 230, 350, 433, 226], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %% [markdown]
# Potential cause for spike on Feb 22:
#
# There was a big winter storm that affected a large part of the East Coast on Feb 20 - 22. This may have may have cause flight delays resulting in a lot of angry passengers.
#
# Sources:
# https://ral.ucar.edu/sites/default/files/public/file_attach/features/PDF%20datastream.pdf
# https://theweek.com/10things/536518/10-things-need-know-today-february22-2015
